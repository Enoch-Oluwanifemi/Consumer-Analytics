# %% [markdown]
# <a href="https://colab.research.google.com/github/Enoch-Oluwanifemi/Consumer-Analytics/blob/main/Review_on_Beats_pill_plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_review = pd.read_csv('cleaned_merged_data.csv')

# %%
beats_pill_reviews = customer_review[customer_review['product_name'] == 'Beats pill plus']
beats_pill_reviews.head()
# Out:
#           review_id  product_id  \
# 601  R1BAI6TH3ZMOHU  B078HG6WNX
# 602  R1ZD1FQESOQBAO  B078HG6WNX
# 603  R2I7GHB3AID4ZC  B078HG6WNX
# 604  R2NAV1PG8X5U68  B078HG6WNX
# 605  R36Q6CZ31TEQPF  B078HG6WNX
#
#                                                  title             author  \
# 601                   5.0 out of 5 stars Amazing Sound      Luis Escobedo
# 602  5.0 out of 5 stars Good product easy to use an...         Joe Manson
# 603             5.0 out of 5 stars Loud little speaker        ryan barton
# 604                5.0 out of 5 stars You will love it              peter
# 605                        5.0 out of 5 stars 😍😍😍😍🔥🔥🔥🔥  Demetrius Murrell
#
#      rating                                            content  \
# 601       5  The bass is amazing, I always needed more volu...
# 602       5         Good in lieu of big expensive sound system
# 603       5  Bought for my son. He streams annoying music. ...
# 604       5  As I got it I wasn’t surprised because it does...
# 605       5                   I love it when it’s loud 🔥🔥🔥🔥🔥🔥🔥
#
#                                           timestamp  \
# 601   Reviewed in the United States August 21, 2024
# 602     Reviewed in the United States June 18, 2022
# 603  Reviewed in the United States December 9, 2022
# 604      Reviewed in the United States July 9, 2020
# 605  Reviewed in the United States December 6, 2023
#
#                        profile_id  is_verified  helpful_count  \
# 601  AH7XO3UATGP5SFUDGO2EXHQW3OJQ            1              0
# 602  AFB5VVEXOTV6LCSJQ3YVYJGQVNBA            1              0
# 603  AF3STZDZPQGKO3QOXNPJTV4SF5GA            1              2
# 604  AFX5HZYMSVQMWCWCPF5VP2S4E6TQ            1              4
# 605  AHRMB2TZPLUK2RAJEMZWGCRIKY7Q            1              0
#
#     product_attributes     product_name sentiment  polarity  subjectivity
# 601       Color: Black  Beats pill plus  Positive   0.23750         0.600
# 602       Color: White  Beats pill plus  Positive   0.15000         0.450
# 603       Color: White  Beats pill plus  Negative  -0.80000         0.900
# 604       Color: Black  Beats pill plus  Positive   0.16675         0.705
# 605       Color: White  Beats pill plus  Positive   0.30000         0.700

# %%
from textblob import TextBlob

def analyze_sentiment(text):
  if text is None:
    return "Neutral"
  analysis = TextBlob(text)
  if analysis.sentiment.polarity > 0:
    return "Positive"
  elif analysis.sentiment.polarity == 0:
    return "Neutral"
  else:
    return "Negative"

beats_pill_reviews['sentiment'] = beats_pill_reviews['content'].apply(analyze_sentiment)
# Out:
# <ipython-input-6-17338f898291>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   beats_pill_reviews['sentiment'] = beats_pill_reviews['content'].apply(analyze_sentiment)

# %%
sentiment_counts = beats_pill_reviews['sentiment'].value_counts()
print(sentiment_counts)
# Out:
# sentiment
# Positive    67
# Neutral     16
# Negative    10
# Name: count, dtype: int64

# %%
import pandas as pd
import google.generativeai as genai

# Replace 'your_api_key' with the actual API key
api_key = "AIzaSyC5UFlEs-3G72H46PZ0ddIKhC4wPgfhaXc"

# Function to analyze reviews using Gemini AI
def analyze_reviews(reviews, api_key,prompt_message):
    genai.configure(api_key=api_key)

    model = genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config={
            "temperature": 1,
            "top_p": 0.95,
            "top_k": 64,
            "max_output_tokens": 8192,
            "response_mime_type": "text/plain",
        },
    )

    chat_session = model.start_chat(history=[])

    prompt = prompt_message + "\n\n".join(reviews)
    response = chat_session.send_message(prompt)
    return response.text

# %%
reviews_column_name = 'content'
reviews = beats_pill_reviews[reviews_column_name].head(100).tolist()

# Send prompts and print results
prompt_message = "Analyze the following reviews and summarize the key insights:"
insights = analyze_reviews(reviews, api_key, prompt_message)
print(insights)
# Out:
# ## Beats Pill+ Speaker Review Summary:
#
# **Positive:**
#
# * **Sound Quality:**  The most consistent praise was for the sound quality, particularly the powerful bass and loud volume.
# * **Portability:**  Reviewers appreciated the compact size and long battery life, making it ideal for outdoor activities, travel, and around the house.
# * **Value for Money:**  Many found the refurbished units to be a great deal, offering a significant discount while still providing excellent performance.
# * **Ease of Use:**  Simple to connect via Bluetooth, charge, and use.
# * **Overall Satisfaction:**  A large number of reviewers expressed their overall satisfaction with the product.
#
# **Negative:**
#
# * **Refurbished Concerns:**  Some reviewers received damaged or malfunctioning refurbished units, highlighting the risks associated with purchasing used electronics.
# * **Battery Life:**  A few reviewers mentioned shorter than advertised battery life, particularly with refurbished models.
# * **Charger Issues:**  Several customers received speakers without chargers, which is a significant drawback.
# * **Quality Control:**  There were reports of inconsistent quality with some units arriving in good condition and others showing signs of wear and tear.
# * **Outdated Technology:**  Some pointed out the use of Lightning charging as outdated, preferring the more modern Type-C.
#
# **Key Insights:**
#
# * **Sound quality is a strong selling point:** Beats Pill+ consistently delivers a satisfying listening experience, particularly for bass-heavy music.
# * **Refurbished units are a gamble:** While potentially offering great value, there's a higher chance of receiving a damaged or faulty product.
# * **Battery life can be inconsistent:**  This seems to be more prevalent with refurbished units, but can also occur with new speakers.
# * **Consider purchasing a new unit:** While cheaper options exist, the newer Beats Pill+ with Type-C charging might be a better long-term investment.
#
# **Overall:**
#
# The Beats Pill+ speaker remains a popular choice for portable audio, offering good sound quality and portability. However, the potential for inconsistent quality and battery issues, particularly with refurbished units, should be considered before purchasing.
